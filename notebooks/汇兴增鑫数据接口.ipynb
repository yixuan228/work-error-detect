# %% [markdown]
# # 汇鑫增鑫饲喂传感器数据接口
#
# 参考协议：增鑫智能精准饲喂器管理平台API接口.pdf

# %% [markdown]
# ## 1. 登入接口

# %%
import requests

BASE_URL = "http://znsw.zxkj2006.com"

# 登入接口返回 token
login_url = BASE_URL + "/feed/api/admin/appLogin"
login_params = {
    "password": "123456",
    "username": "漯河汇兴"
}

login_resp = requests.post(login_url, json=login_params)
login_json = login_resp.json()
token = login_json["data"].get("token")
headers = {
    "AuthorizationF": f"Bearer {token}"
}

print(login_resp.status_code)
print(login_resp.text)
# Out:
# 200
# {"code":200,"message":"操作成功","data":{"tokenHead":"Bearer ","token":"eyJhbGciOiJIUzUxMiJ9.eyJzdWIiOiLmvK_msrPmsYflhbQiLCJjcmVhdGVkIjoxNzY4OTYxMzc1MzkwLCJleHAiOjE3Njk4MjUzNzV9.n_JZ2uD9LKSIc3hWFXjRdPscwA7rl1syRVqOFAi-4pJH2t5oY46YisaE55c_-HfygTPSfKXSX2yze9QJTSawfQ"}}

# %% [markdown]
# ## 2. 接入栏喂食数据

# %%
column_feed_url = BASE_URL + "/feed/api/api/v1/data/exportRecordInfo"
column_feed_params = {
    "areaId": "1017517",  
    "startDate": "2025-12-01",  
    "endDate": "2025-12-31",  
    "earTag": "",  
    "lsId": "10278",  
    "flag": 1
}

column_feed_resp = requests.post(column_feed_url, json=column_feed_params, headers=headers)

# %%
column_feed_resp
# Out:
# <Response [200]>

# %%
print(column_feed_resp.status_code)
# Out:
# 200

# %%
column_feed_resp.content
# Out:
# b'{"\xe6\x8f\x90\xe7\xa4\xba":"\xe4\xb8\x8b\xe8\xbd\xbd\xe6\x96\x87\xe4\xbb\xb6\xe5\xa4\xb1\xe8\xb4\xa5\xef\xbc\x8c\xe5\xaf\xbc\xe5\x87\xba\xe7\x9a\x84\xe6\x95\xb0\xe6\x8d\xae\xe6\x9c\x89\xe8\xaf\xaf\xe6\x88\x96\xe4\xb8\x8d\xe8\x83\xbd\xe4\xb8\xba\xe7\xa9\xba\xef\xbc\x81"}\n'
